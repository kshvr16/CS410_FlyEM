# %%
import os
import time
from tqdm.notebook import tqdm
from image.controller import ImageController

# %%
dir_path = "/hpcstor6/scratch01/s/s.kona001/flyem/test_images/real_images"

# %%
for file in tqdm(os.listdir(dir_path)):
    start_time = time.time()
    if file.endswith(".tif"):
        print("Image Name: " + file)
        img_file = os.path.join(dir_path, file)
        data = ImageController.read(img_file)
        normalized_data = ImageController.normalize(data)
        crop_data = ImageController.center_crop(normalized_data)
        smoothed_data = ImageController.smooth(crop_data)
        for threshold in tqdm(range(150, 0, -1)):
            threshold_data = ImageController.threshold(smoothed_data, threshold_value=threshold)
            labeled_data, nr_count = ImageController.label(threshold_data)
            selected_labeled_data = ImageController.select_regions(labeled_data, region_size=1500)
            binary_mask_data = ImageController.binary_mask(selected_labeled_data)
            closed_binary_mask_data = ImageController.close_binary_mask(binary_mask_data)
            segmented_image = ImageController.binary_image(closed_binary_mask_data)
            if ImageController.classify_image(binary_mask_data):
                print("Threshold value: ", threshold)
                ImageController.display(segmented_image)
                break
        end_time = time.time()
        print("Total Time Taken: ", (end_time - start_time), " seconds")
        print("---------------------------------------------------------")
# Out:
#   0%|          | 0/31 [00:00<?, ?it/s]
# Image Name: image_000000_000000_000431_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  79
# Total Time Taken:  1.7756688594818115  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000162_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Total Time Taken:  4.303447961807251  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000511_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  60
# Total Time Taken:  2.135028839111328  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000100_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Total Time Taken:  4.567225933074951  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000342_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  96
# Total Time Taken:  1.4682142734527588  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000227_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Total Time Taken:  5.121454477310181  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000231_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Total Time Taken:  5.058526277542114  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000329_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  97
# Total Time Taken:  1.4533014297485352  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000313_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  101
# Total Time Taken:  1.3867955207824707  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000376_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  89
# Total Time Taken:  1.5744776725769043  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000305_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  102
# Total Time Taken:  1.676504135131836  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000005_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Total Time Taken:  5.08388352394104  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000471_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  74
# Total Time Taken:  1.8527240753173828  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000402_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  87
# Total Time Taken:  1.6324946880340576  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000334_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  99
# Total Time Taken:  1.4127528667449951  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000181_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Total Time Taken:  4.095362186431885  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000338_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  96
# Total Time Taken:  1.450345754623413  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000008_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Total Time Taken:  5.154255151748657  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000435_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  75
# Total Time Taken:  1.8275482654571533  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000523_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  49
# Total Time Taken:  2.3642752170562744  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000432_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  78
# Total Time Taken:  1.762153148651123  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000261_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Total Time Taken:  5.281518220901489  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000391_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  85
# Total Time Taken:  1.6739821434020996  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000403_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Total Time Taken:  4.920983791351318  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000480_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  61
# Total Time Taken:  2.1230857372283936  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000235_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Total Time Taken:  5.098999977111816  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000379_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Total Time Taken:  4.763918876647949  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000437_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  75
# Total Time Taken:  1.8293204307556152  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000310_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Total Time Taken:  5.017603158950806  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000479_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Threshold value:  61
# Total Time Taken:  2.1226136684417725  seconds
# ---------------------------------------------------------
# Image Name: image_000000_000000_000085_000000.tif
#   0%|          | 0/150 [00:00<?, ?it/s]
# Total Time Taken:  4.5762176513671875  seconds
# ---------------------------------------------------------
